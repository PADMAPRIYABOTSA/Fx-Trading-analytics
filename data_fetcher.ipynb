# %%
# !pip install pandas numpy requests plotly statsmodels schedule
# Out:
# Requirement already satisfied: pandas in c:\users\botsa\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\botsa\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: requests in c:\users\botsa\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: plotly in c:\users\botsa\anaconda3\lib\site-packages (5.24.1)
# Requirement already satisfied: statsmodels in c:\users\botsa\anaconda3\lib\site-packages (0.14.4)
# Requirement already satisfied: schedule in c:\users\botsa\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\botsa\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\botsa\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\botsa\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\botsa\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\botsa\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\botsa\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\botsa\anaconda3\lib\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\botsa\anaconda3\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\botsa\anaconda3\lib\site-packages (from plotly) (24.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\botsa\anaconda3\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\botsa\anaconda3\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\botsa\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta

# %%
def fetch_fx_data(pair="EURUSD=X",period="60d",interval="1h"):
    data=yf.download(
        tickers=pair,
        period=period,
        interval=interval,
        auto_adjust=True #adjusts any splits/dividends
        
    )
    data.columns=data.columns.droplevel(1)
    data['Volume']=data['Volume'].replace(0,1)
    if data.empty:
        raise ValueError(f"No data returned for {pair}")
    return data
if __name__=="__main__":
    df=fetch_fx_data()
    print(df.shape)
    print(df.head(5))
    df.to_csv("raw_fx_data")
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1418, 5)
# Price                         Close      High       Low      Open  Volume
# Datetime
# 2026-03-09 00:00:00+00:00  1.152074  1.153403  1.151941  1.152605       1
# 2026-03-09 01:00:00+00:00  1.151278  1.152605  1.151145  1.151941       1
# 2026-03-09 02:00:00+00:00  1.152871  1.153004  1.151278  1.151543       1
# 2026-03-09 03:00:00+00:00  1.151941  1.153136  1.151676  1.153136       1
# 2026-03-09 04:00:00+00:00  1.152871  1.153270  1.151941  1.152206       1

# %%
da.to_parquet("data_fetcher_op.parquet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_fetcher.to_parquet("data_fetcher_op.parquet")
#
# NameError: name 'data_fetcher' is not defined
